# %%
#Ishrat Amin
#CSCI381
#Professor : Matthew Fried

# %% [markdown]
# # Introduction

# %%
# Attribute Information:


# Input variables 
# 1 -  Index
# 2 -  TARGET
# 3 - FixedAcidity
# 4 - VolatileAcidity
# 5 - CitricAcid
# 6 - ResidualSugar
# 7 - Chlorides
# 8 - FreeSulfurDioxide
# 9 - TotalSulfurDioxide
# 10 - Density
# 11 - pH
# 12 - Sulphates
# 13 - Alcohol
# 14 - LabelAppeal
# 15 - AcidIndex
# 16 - STARS

# Step 1  :Loaded the provided file.
# Step 2  : I will do EDA of each Input Variable and do graphical analysis.
# Step 3  : If there any missing values,depending on table i will fill those/drop it.
# Step 4  : I will use scaling methods if necessary.
# Step 5  : Re-run EDA analysis,to undestand the improvement

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


url = "https://raw.githubusercontent.com/MatthewFried/Udemy/master/Day2/Day2_Data.csv"

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#        INDEX  TARGET  FixedAcidity  VolatileAcidity  CitricAcid  \
# 0          1       3           3.2            1.160       -0.98
# 1          2       3           4.5            0.160       -0.81
# 2          4       5           7.1            2.640       -0.88
# 3          5       3           5.7            0.385        0.04
# 4          6       4           8.0            0.330       -1.26
# ...      ...     ...           ...              ...         ...
# 12790  16120       0           5.0           -0.790        2.01
# 12791  16123       5           8.9            0.470        0.29
# 12792  16127       4           6.0            0.170       -1.10
# 12793  16128       3           7.7            0.320        0.12
# 12794  16129       4           5.2           -0.040       -0.81
#
#        ResidualSugar  Chlorides  FreeSulfurDioxide  TotalSulfurDioxide  \
# 0               54.2     -0.567                NaN               268.0
# ...

# %%
#We can see there are few missing datas in the dataframe which is issues of potential data integrity.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12795 entries, 0 to 12794
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   INDEX               12795 non-null  int64
#  1   TARGET              12795 non-null  int64
#  2   FixedAcidity        12795 non-null  float64
#  3   VolatileAcidity     12795 non-null  float64
#  4   CitricAcid          12795 non-null  float64
#  5   ResidualSugar       12179 non-null  float64
#  6   Chlorides           12157 non-null  float64
#  7   FreeSulfurDioxide   12148 non-null  float64
#  8   TotalSulfurDioxide  12113 non-null  float64
#  9   Density             12795 non-null  float64
#  10  pH                  12400 non-null  float64
#  11  Sulphates           11585 non-null  float64
#  12  Alcohol             12142 non-null  float64
#  13  LabelAppeal         12795 non-null  int64
#  14  AcidIndex           12795 non-null  int64
# ...

# %%
fig = df.hist(figsize=(12,12),color ='blue')

# %%
#Below datasets have large number in dataframe which will be hard to work on

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.boxplot(df["TARGET"])
# Out:
# C:\Users\Ishrat Amin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TARGET'>

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.boxplot(df["ResidualSugar"])
# Out:
# C:\Users\Ishrat Amin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ResidualSugar'>

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.boxplot(df["FreeSulfurDioxide"])
# Out:
# C:\Users\Ishrat Amin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FreeSulfurDioxide'>

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.boxplot(df["TotalSulfurDioxide"])
# Out:
# C:\Users\Ishrat Amin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalSulfurDioxide'>

# %%
#From i can clearly say that above table has Nan values. To fill those values, i will follow below rules

# %%
df.isnull().sum()
# Out:
# INDEX                    0
# TARGET                   0
# FixedAcidity             0
# VolatileAcidity          0
# CitricAcid               0
# ResidualSugar          616
# Chlorides              638
# FreeSulfurDioxide      647
# TotalSulfurDioxide     682
# Density                  0
# pH                     395
# Sulphates             1210
# Alcohol                653
# LabelAppeal              0
# AcidIndex                0
# STARS                 3359
# dtype: int64

# %% [markdown]
# # Scaling

# %%
df['ResidualSugar'].fillna(df["ResidualSugar"].mean(),inplace = True)

# %%
df['Chlorides'].fillna(df["Chlorides"].mean(),inplace = True)

# %%
df['FreeSulfurDioxide'].fillna(df["FreeSulfurDioxide"].mean(),inplace = True)

# %%
df['TotalSulfurDioxide'].fillna(df["TotalSulfurDioxide"].mean(),inplace = True)

# %%
df['pH'].fillna(df["pH"].mean(),inplace = True)

# %%
df['Sulphates'].fillna(df["Sulphates"].mean(),inplace = True)

# %%
df['Alcohol'].fillna(df["Alcohol"].mean(),inplace = True)

# %%
df['STARS'].fillna(df["STARS"].mean(),inplace = True)

# %%
df
# Out:
#        INDEX  TARGET  FixedAcidity  VolatileAcidity  CitricAcid  \
# 0          1       3           3.2            1.160       -0.98
# 1          2       3           4.5            0.160       -0.81
# 2          4       5           7.1            2.640       -0.88
# 3          5       3           5.7            0.385        0.04
# 4          6       4           8.0            0.330       -1.26
# ...      ...     ...           ...              ...         ...
# 12790  16120       0           5.0           -0.790        2.01
# 12791  16123       5           8.9            0.470        0.29
# 12792  16127       4           6.0            0.170       -1.10
# 12793  16128       3           7.7            0.320        0.12
# 12794  16129       4           5.2           -0.040       -0.81
#
#        ResidualSugar  Chlorides  FreeSulfurDioxide  TotalSulfurDioxide  \
# 0          54.200000  -0.567000          30.845571          268.000000
# ...

# %%
df.isnull().sum()
# Out:
# INDEX                 0
# TARGET                0
# FixedAcidity          0
# VolatileAcidity       0
# CitricAcid            0
# ResidualSugar         0
# Chlorides             0
# FreeSulfurDioxide     0
# TotalSulfurDioxide    0
# Density               0
# pH                    0
# Sulphates             0
# Alcohol               0
# LabelAppeal           0
# AcidIndex             0
# STARS                 0
# dtype: int64

# %%
# If we look at the dataframe, compare to other columns 
# ResidualSugar,FreeSulfurDioxide and TotalSulfurDioxide have large numbers
 # So i will apply scaling method those three columns

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mx = MinMaxScaler()

# %%
df['ResidualSugar'] = mx.fit_transform(df['ResidualSugar'].values.reshape(-1,1))

# %%
df['FreeSulfurDioxide'] = mx.fit_transform(df['FreeSulfurDioxide'].values.reshape(-1,1))

# %%
df['TotalSulfurDioxide'] = mx.fit_transform(df['TotalSulfurDioxide'].values.reshape(-1,1))

# %%
df.head()
# Out:
#    INDEX  TARGET  FixedAcidity  VolatileAcidity  CitricAcid  ResidualSugar  \
# 0      1       3           3.2            1.160       -0.98       0.676706
# 1      2       3           4.5            0.160       -0.81       0.572225
# 2      4       5           7.1            2.640       -0.88       0.530210
# 3      5       3           5.7            0.385        0.04       0.545083
# 4      6       4           8.0            0.330       -1.26       0.510132
#
#    Chlorides  FreeSulfurDioxide  TotalSulfurDioxide  Density    pH  Sulphates  \
# 0  -0.567000           0.497322            0.580319  0.99280  3.33      -0.59
# 1  -0.425000           0.483871            0.263830  1.02792  3.38       0.70
# 2   0.037000           0.652801            0.513298  0.99518  3.12       0.48
# 3  -0.425000           0.489813            0.498936  0.99640  2.24       1.83
# 4   0.054822           0.329372            0.495213  0.99457  3.12       1.77
#
#      Alcohol  LabelAppeal  AcidIndex  STARS
# ...

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.boxplot(df["ResidualSugar"])
# Out:
# C:\Users\Ishrat Amin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ResidualSugar'>

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.boxplot(df["FreeSulfurDioxide"])
# Out:
# C:\Users\Ishrat Amin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FreeSulfurDioxide'>

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.boxplot(df["TotalSulfurDioxide"])
# Out:
# C:\Users\Ishrat Amin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalSulfurDioxide'>

# %%
# There is a slight, but not insignificant difference here. 
# Demonstrating that the re-scaling of a few variables had no effect on the full data frame.
# We wanted to achieve this since replacing them with the'mean' value usually preserves data integrity.

# %% [markdown]
# # Conclusion
#
# Wines with a good quantity of density and pH received more stars. This is an excellent dataframe for learning about wine. People will gain a good understanding of wine as a result of this dataset.

# %% [markdown]
# # Source
#
# https://archive.ics.uci.edu/ml/datasets/Wine+Quality
# https://winefolly.com/deep-dive/understanding-acidity-in-wine/
