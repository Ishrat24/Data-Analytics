# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

url = "https://raw.githubusercontent.com/Ishrat24/Data-Analytics/main/Assignment/diamonds.csv"

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.rename( columns={'Unnamed: 0':'a'}, inplace=True )

# %%
df
# Out:
#            a  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935  53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# ...

# %%
df.drop("a",axis=1)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#Part 1


# Using Pandas 
# To count use cases of data set,attribute of each use case. .
# There is a function Called count().

# Use cases = 53940
# Attribute = 10

df.count()
# Out:
# a          53940
# carat      53940
# cut        53940
# color      53940
# clarity    53940
# depth      53940
# table      53940
# price      53940
# x          53940
# y          53940
# z          53940
# dtype: int64

# %%
#Here are the dta types of each attribute.

df.dtypes
# Out:
# a            int64
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
#Part 2


#2

# price :
    # price in US dollars (\$326--\$18,823)
# carat:
    # weight of the diamond (0.2--5.01)
# cut:
    # quality of the cut (Fair, Good, Very Good, Premium, Ideal)
# color:
    # diamond colour, from D (best) to J (worst)
# clarity:
    # a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# x:
    # length in mm (0--10.74)
# y:
    # width in mm (0--58.9)
# z:
    # depth in mm (0--31.8)
# depth:
    # total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
# table:
    # width of top of diamond relative to widest point (43--95)

# %%
#Here i should Graphical analysis for carat using Matplotlib
plt.figure(figsize=(12,4), dpi=200)
carat = df['carat'].hist(edgecolor = "black")
carat.set_title('Carat Histogram')
# Out:
# Text(0.5, 1.0, 'Carat Histogram')

# %%
#Here i should Graphical analysis for depth using Matplotlib

plt.figure(figsize=(12,4), dpi=200)
depth = df['depth'].hist(edgecolor = "black")

depth.set_title('Depth Histogram')
# Out:
# Text(0.5, 1.0, 'Depth Histogram')

# %%
#Here i should Graphical analysis for carat using Seaborn
plt.figure(figsize=(12,4), dpi=200)
sns.histplot(df , x = "carat")
# Out:
# <AxesSubplot:xlabel='carat', ylabel='Count'>

# %%
#Here i should Graphical analysis for depth using Seaborn

plt.figure(figsize=(12,4), dpi=200)
sns.histplot(df , x = "depth")
# Out:
# <AxesSubplot:xlabel='depth', ylabel='Count'>

# %%
plt.figure(figsize=(12,4), dpi=200)
sns.histplot(df , x = "carat")
# Out:
# <AxesSubplot:xlabel='carat', ylabel='Count'>

# %%
plt.figure(figsize=(12,4), dpi=200)
sns.histplot(df , x = "cut")
# Out:
# <AxesSubplot:xlabel='cut', ylabel='Count'>

# %%
plt.figure(figsize=(12,4), dpi=200)
sns.histplot(df , x = "color")
# Out:
# <AxesSubplot:xlabel='color', ylabel='Count'>

# %%
plt.figure(figsize=(12,4), dpi=200)
sns.histplot(df , x = "clarity")
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='Count'>

# %%
plt.figure(figsize=(12,4), dpi=200)
sns.histplot(df , x = "depth")
# Out:
# <AxesSubplot:xlabel='depth', ylabel='Count'>

# %%
plt.figure(figsize=(12,4), dpi=200)
sns.histplot(df , x = "table")
# Out:
# <AxesSubplot:xlabel='table', ylabel='Count'>

# %%
plt.figure(figsize=(12,4), dpi=200)
sns.histplot(df , x = "price")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
plt.figure(figsize=(12,4), dpi=200)
sns.histplot(df , x = "x")
# Out:
# <AxesSubplot:xlabel='x', ylabel='Count'>

# %%
plt.figure(figsize=(12,4), dpi=200)
sns.histplot(df , x = "y")
# Out:
# <AxesSubplot:xlabel='y', ylabel='Count'>

# %%
plt.figure(figsize=(12,4), dpi=200)

sns.histplot(df , x = "z")
# Out:
# <AxesSubplot:xlabel='z', ylabel='Count'>

# %%
##Part3

#1
columns = df.loc[(df['carat']>=.30) & (df['carat'] <= 1.08)  , 'carat']

# %%
print(columns)
# Out:
# 4        0.31
# 10       0.30
# 13       0.31
# 15       0.32
# 16       0.30
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 40284, dtype: float64

# %%
length_cols = len(columns)

proportion = (length_cols / len(df['carat'])) * 100

print(proportion)
# Out:
# 74.68298109010011

# %%
#2

equal= df.loc[(df['x'] == df['y'])]

equal_dimension =len(equal)
print(equal_dimension)
# Out:
# 17

# %%
#3

carat = df['carat'].values
mean_carat = carat.mean()
print(mean_carat)
# Out:
# 0.7979397478680014

# %%
value = df.loc[(df['carat'] < mean_carat )]

# %%
print(len(value))
# Out:
# 31127

# %%
#4

cut_quality = df.loc[(df['cut'].str.contains("Premium")) | (df['cut'].str.contains("Ideal")) ]

# %%
print(len(cut_quality))
# Out:
# 35342

# %%
#5

max_price = (df['price'].max())
print(max_price)
# Out:
# 18823

# %%
value = df.loc[max_price , 'carat']

# %%
print(value)
# Out:
# 1.26

# %%
#6
#Plotting using Matplotlib

plt.figure(figsize=(12,4), dpi=200)
plt.boxplot(df['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2261d34ea30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2261d34efd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2261d34e760>],
#  'medians': [<matplotlib.lines.Line2D at 0x2261d35c5b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2261d35c880>],
#  'means': []}

# %%
#Plotting using seaborn

plt.figure(figsize=(12,4), dpi=200)
sns.boxplot(df['price'])
# Out:
# C:\Users\Ishrat Amin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
# Conclusion :
#  As the cut is getting higher, diamond's price becoming more expensive.

# %%
#7

#Plotting using seaborn
plt.figure(figsize=(12,4), dpi=200)
sns.scatterplot(x ='price' , y = 'carat', data=df )
# Out:
# <AxesSubplot:xlabel='price', ylabel='carat'>

# %%
#Plotting using Matplotlib

plt.figure(figsize=(12,4), dpi=200)
plt.scatter(df['price'] , df['carat'])

# %%
# As the price is getting higher, carat's number is getting higher too.So relation between price vs carat is Propotional.

# %%
#Part 4

# Finally, this job provides an easy way to learn about diamonds. People will become familiar with carat, cut, color, and other key facts about diamonds as a result of this work, which will benefit them in the future. When they go to the market to buy diamonds.
# People will also learn how to cut, color impacts on price.
# Even if the market price does not remain constant, consumers will continue to buy.

# have some understanding of diamonds

# The graphical study is also a fantastic example of how price impacts carat.

# %%
# Source :
    
#     1.https://www.geeksforgeeks.org/
#     2.https://www.youtube.com/
#     3.https://ggplot2.tidyverse.org/reference/diamonds.html
#     4.https://stackoverflow.com/
